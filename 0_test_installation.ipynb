# %%
# LEARNING: Testing LangGraph Installation
# This is the first step to verify that LangGraph is properly installed in the environment.
# StateGraph is the core class in LangGraph used to build stateful, multi-step workflows.
# It allows you to define nodes (functions) and edges (transitions) to create complex AI workflows.
from langgraph.graph import StateGraph
